# %%
import csv
import pandas as pd

filename = "StatewiseTestingDetails.csv"

fields = []
rows = []

with open(filename, 'r') as csvfile:
    
    csvreader = csv.reader(csvfile)
    
    fields = next(csvreader)
    
    # extracting each data row one by one 
    for row in csvreader:
        rows.append(row)
    
    # get total number of rows 
    print("Total no. of rows: %d" %(csvreader.line_num)) 
  
# printing the field names 
print('Field names are:' + ', '.join(field for field in fields)) 
  
#  printing first 5 rows 
print('\nFirst 5 rows are:\n') 
for row in rows[:5]: 
    # parsing each column of a row 
    for col in row: 
        print("%10s"%col), 
#     print('\n')
# Out:
# Total no. of rows: 7999
# Field names are:Date, State, TotalSamples, Negative, Positive
#
# First 5 rows are:
#
# 2020-04-01
#      Delhi
#       2621
#
#
# 2020-04-01
#     Kerala
#       7965
#       7256
#        265
# 2020-04-01
# West Bengal
#        659
#        568
#         37
# 2020-04-02
# Andhra Pradesh
#       1800
#       1175
#        132
# 2020-04-02
#      Assam
#        962
#        819
#         16

# %%
import pandas as pd

df = pd.read_csv(
    'StatewiseTestingDetails.csv',
    header = None,
    sep = ',',
)

print(df.columns)
print(df.head(10))
# Out:
# Int64Index([0, 1, 2, 3, 4], dtype='int64')
#             0               1             2         3         4
# 0        Date           State  TotalSamples  Negative  Positive
# 1  2020-04-01           Delhi          2621       NaN       NaN
# 2  2020-04-01          Kerala          7965      7256       265
# 3  2020-04-01     West Bengal           659       568        37
# 4  2020-04-02  Andhra Pradesh          1800      1175       132
# 5  2020-04-02           Assam           962       819        16
# 6  2020-04-02      Chandigarh           124        98        18
# 7  2020-04-02    Chhattisgarh          1232       921         9
# 8  2020-04-02             Goa           220       197         5
# 9  2020-04-02          Kerala          8456      7622       286

# %%
import pandas as pd
import numpy as np 
import csv

reader = csv.reader(open('StatewiseTestingDetails.csv'))
result = {}
for row in reader:
    key = row[0]
    if key in result:
        # implement your duplicate row handling here
        pass
    result[key] = row[1:]
# print(result)
# df = pd.DataFrame(result, index = ['a','b','c','d','e','f'])

# print(df)
print("............")

# df_filtered = df.query("Positive>10")
# print(df_filtered)
# Out:
# ............

# %%
import pandas as pd

def convert_num(cell):
    if cell<str(2):
        return 34
    return cell

df = pd.read_csv("StatewiseTestingDetails.csv", na_values=["NaN"])
df
# Out:
#             Date           State  TotalSamples Negative  Positive
# 0     2020-04-01           Delhi          2621      NaN       NaN
# 1     2020-04-01          Kerala          7965     7256     265.0
# 2     2020-04-01     West Bengal           659      568      37.0
# 3     2020-04-02  Andhra Pradesh          1800     1175     132.0
# 4     2020-04-02           Assam           962      819      16.0
# ...          ...             ...           ...      ...       ...
# 7993  2020-12-06       Telangana       5779490      NaN       NaN
# 7994  2020-12-06         Tripura        540088   507200   32888.0
# 7995  2020-12-06   Uttar Pradesh      20308636      NaN       NaN
# 1802  2020-06-06  Tamil Nadu        576695   545896   30152.0
# 1834  2020-06-07  Tamil Nadu        592970   560890   31667.0
# 1865  2020-06-08  Tamil Nadu        607952   574209   33229.0
# 1897  2020-06-09  Tamil Nadu        621171   585678   34914.0
# 1929  2020-06-10  Tamil Nadu        638846   601363   36841.0
# 1962  2020-06-11  Tamil Nadu        655675   616395   38716.0
# 1993  2020-06-12  Tamil Nadu        673906   632656   40698.0
# 2026  2020-06-13  Tamil Nadu        691817   648545   42687.0
# 2057  2020-06-14  Tamil Nadu        710599   665401   44661.0
# 2091  2020-06-15  Tamil Nadu        729002   681961   46504.0
# 2124  2020-06-16  Tamil Nadu        748244   699645   48019.0
# 2158  2020-06-17  Tamil Nadu        773707   722830   50193.0
# 2192  2020-06-18  Tamil Nadu        800443   747428   52334.0
# 2225  2020-06-19  Tamil Nadu        827980   772937   54449.0
# 2259  2020-06-20  Tamil Nadu        861211   803824   56845.0
# 2293  2020-06-21  Tamil Nadu        892612   832720   59377.0
# 2328  2020-06-22  Tamil Nadu        919204   856475   62087.0
# 2363  2020-06-23  Tamil Nadu        944352   879176   64603.0
# 2398  2020-06-24  Tamil Nadu        976431   908292   67468.0
# 2433  2020-06-25  Tamil Nadu       1008974   937412   70977.0
# 2467  2020-06-26  Tamil Nadu       1042649   967356   74622.0
# 2502  2020-06-27  Tamil Nadu       1077454   998543   78335.0

# %%
df.head()
# Out:
#          Date           State  TotalSamples Negative  Positive
# 0  2020-04-01           Delhi          2621      NaN       NaN
# 1  2020-04-01          Kerala          7965     7256     265.0
# 2  2020-04-01     West Bengal           659      568      37.0
# 3  2020-04-02  Andhra Pradesh          1800     1175     132.0
# 4  2020-04-02           Assam           962      819      16.0

# %%
timestamp = []

filt = df[df["Date"] == "2020-04-01"]
for i in df:
    timestamp.append(filt)
    
for x in timestamp:
    print(x)
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 7993    False
# 7994    False
# 7995    False
# 7996    False
# 7997    False
# Name: Date, Length: 7998, dtype: bool
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 7993    False
# 7994    False
# 7995    False
# 7996    False
# 7997    False
# Name: Date, Length: 7998, dtype: bool
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 7993    False
# 7994    False
# 7995    False
# 7996    False
# 7997    False
# Name: Date, Length: 7998, dtype: bool
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 7993    False
# 7994    False
# 7995    False
# 7996    False
# 7997    False
# Name: Date, Length: 7998, dtype: bool
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 7993    False
# 7994    False
# 7995    False
# 7996    False
# 7997    False
# Name: Date, Length: 7998, dtype: bool
